# %% [markdown]
# ## tuple, set, dictionary 실습

# %% [markdown]
# byte, bytes, bytearray, range

# %% [markdown]
# all() any()

# %%
numbers = [10,20,30]
numbers += [40,50]
numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers =set([1,2,3,1,2,3,4,5,6])
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
fruits = {"apple","apple", "banana", "cherry"}
if "apple" in fruits: 
    print("집합 안에 apple이 있습니다.")
# Out:
# 집합 안에 apple이 있습니다.

# %%
fruits = {"apple", "banana", "cherry"}
size = len(fruits)
print(size)
# Out:
# 3
