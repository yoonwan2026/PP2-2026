# %% [markdown]
# ## tuple, set, dictionary 실습

# %% [markdown]
# byte, bytes, bytearray, range

# %%
numbers = [10,20,30]
numbers += [40,50]
numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers =set([1,2,3,1,2,3,4,5,6])
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6}
