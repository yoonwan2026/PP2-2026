# %% [markdown]
# ## Typehint 연습
#
# 이 파일은 파이썬의 typehint 예제와 이론을 실습한 결과입니다
# 작성자: 윤완 작성일: 9.15

# %% [markdown]
# 타입힌트는 함수의 매개변수와 변환값의 타입을 지정하는 목적으로 사용하며 염격한 타입지정으로 인한 프로그래머의 의도를 명확히 전달하기 위함이다 안써도 되지만 파이썬 13부터는 쓴즌 것을 권장하고 있다

# %%
def greet(msg) :
    print("in greet:", msg)
    return msg + "!"

print(greet("안녕"))
(greet(3.141592))
# Out:
# in greet: 안녕
# 안녕!
# in greet: 3.141592
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2     print("in greet:", msg)
#       3     return msg + "!"
#       4
#       5 print(greet("안녕"))
# ----> 6 (greet(3.141592))
#
# Cell In[2], line 3, in greet(msg)
#       1 def greet(msg) :
#       2     print("in greet:", msg)
# ----> 3     return msg + "!"
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
